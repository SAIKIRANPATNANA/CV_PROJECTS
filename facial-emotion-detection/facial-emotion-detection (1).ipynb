# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.3/721.3 kB 13.2 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import warnings as warn
warn.filterwarnings('ignore')
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.11.4 torch-2.2.1+cu121 CPU (AMD Ryzen 3 3250U with Radeon Graphics)
# Setup complete ✅ (4 CPUs, 7.4 GB RAM, 271.2/467.9 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# !yolo task=classify mode=train model=yolov8m-cls.pt data='/kaggle/input/face-expression-recognition-dataset/images' epochs=100 imgsz=48
# Out:
# ...
# 100%|███████████████████████████████████████| 32.7M/32.7M [00:00<00:00, 202MB/s]
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...

# %%
# !yolo task=classify mode=val model='/kaggle/working/runs/classify/train/weights/best.pt' data='/kaggle/input/face-expression-recognition-dataset/images'
# Out:
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# YOLOv8m-cls summary (fused): 103 layers, 15771623 parameters, 0 gradients, 41.6 GFLOPs
# train: /kaggle/input/face-expression-recognition-dataset/images/train... found 28821 images in 7 classes ✅
# val: /kaggle/input/face-expression-recognition-dataset/images/validation... found 7066 images in 7 classes ✅
# test: None...
# val: Scanning /kaggle/input/face-expression-recognition-dataset/images/validatio
# val: WARNING ⚠️ Cache directory /kaggle/input/face-expression-recognition-dataset/images is not writeable, cache not saved.
#                classes   top1_acc   top5_acc: 100%|██████████| 442/442 [00:04<00
#                    all       0.72      0.992
# Speed: 0.0ms preprocess, 0.5ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
Image('/kaggle/working/runs/classify/val/val_batch0_pred.jpg',width=600)

# %%
# !yolo task=classify mode=predict model= '/kaggle/working/runs/classify/train/weights/best.pt' conf=0.25 source="/kaggle/input/face-expression-recognition-dataset/images/validation/happy/10074.jpg"
# Out:
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# YOLOv8m-cls summary (fused): 103 layers, 15771623 parameters, 0 gradients, 41.6 GFLOPs
#
# image 1/1 /kaggle/input/face-expression-recognition-dataset/images/validation/happy/10074.jpg: 64x64 happy 0.98, neutral 0.01, surprise 0.00, fear 0.00, sad 0.00, 6.9ms
# Speed: 7.3ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=classify mode=predict model= '/kaggle/working/runs/classify/train/weights/best.pt' conf=0.25 source='/kaggle/input/face-expression-recognition-dataset/images/validation/surprise/10837.jpg'
# Out:
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# YOLOv8m-cls summary (fused): 103 layers, 15771623 parameters, 0 gradients, 41.6 GFLOPs
#
# image 1/1 /kaggle/input/face-expression-recognition-dataset/images/validation/surprise/10837.jpg: 64x64 surprise 0.93, fear 0.06, happy 0.00, sad 0.00, neutral 0.00, 4.4ms
# Speed: 2.6ms preprocess, 4.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to runs/classify/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=classify mode=predict model= '/kaggle/working/runs/classify/train/weights/best.pt' conf=0.25 source='/kaggle/input/face-expression-recognition-dataset/images/validation/neutral/10787.jpg'
# Out:
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# YOLOv8m-cls summary (fused): 103 layers, 15771623 parameters, 0 gradients, 41.6 GFLOPs
#
# image 1/1 /kaggle/input/face-expression-recognition-dataset/images/validation/neutral/10787.jpg: 64x64 neutral 0.69, sad 0.22, fear 0.04, happy 0.02, angry 0.01, 4.8ms
# Speed: 2.1ms preprocess, 4.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to runs/classify/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=classify mode=predict model= '/kaggle/working/runs/classify/train/weights/best.pt' conf=0.25 source='/kaggle/input/emotion-images/surprise1.jpeg'
# Out:
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# YOLOv8m-cls summary (fused): 103 layers, 15771623 parameters, 0 gradients, 41.6 GFLOPs
#
# image 1/1 /kaggle/input/emotion-images/surprise1.jpeg: 64x64 fear 0.56, angry 0.25, happy 0.08, surprise 0.07, sad 0.03, 4.3ms
# Speed: 2.6ms preprocess, 4.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to runs/classify/predict17
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=classify mode=predict model= 'best.pt' conf=0.5 source='/home/user/Documents/ML_DL_PROJECTS/FacialEmotionDetectionCVProject/prabhas.jpeg'
# Out:
# /home/user/.local/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Ultralytics YOLOv8.1.24 🚀 Python-3.11.4 torch-2.2.1+cu121 CPU (AMD Ryzen 3 3250U with Radeon Graphics)
# YOLOv8m-cls summary (fused): 103 layers, 15771623 parameters, 0 gradients, 41.6 GFLOPs
#
# image 1/1 /home/user/Documents/ML_DL_PROJECTS/FacialEmotionDetectionCVProject/prabhas.jpeg: 64x64 neutral 0.48, sad 0.40, angry 0.08, happy 0.03, fear 0.01, 98.1ms
# Speed: 19.0ms preprocess, 98.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
